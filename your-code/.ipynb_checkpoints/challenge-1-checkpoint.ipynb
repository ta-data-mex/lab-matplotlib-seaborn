# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here

! pip install matplotlib
import matplotlib.pyplot as plt

import seaborn as sns
# %matplotlib inline

import numpy as np
import pandas as pd
# Out:
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\indir\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: matplotlib in c:\users\indir\appdata\local\programs\python\python310\lib\site-packages (3.5.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\indir\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.22.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\indir\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\indir\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.29.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\indir\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\indir\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\indir\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\indir\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\indir\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\indir\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)

plt.subplots()
ax1 = plt.subplot(2,1,1)
ax1.plot(x,y)
ax2 = plt.subplot(2,1,2)
ax2.plot(x,z)
plt.show();

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
fig, ax = plt.subplots(nrows=2,ncols=1)
ax[0].plot(x,y)
ax[1].plot(x,z)
plt.show()

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here

fig, ax = plt.subplots(nrows=2,ncols=1, figsize=(7,6))
ax[0].plot(x,y)
ax[1].plot(x,z)
plt.show()

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here

fig, ax = plt.subplots(nrows=2,ncols=1,sharex=False, figsize=(7,6))

ax[0].plot(x,y)
#ax[0].set_xlabel("set_xlabel")
ax[0].set_ylabel("set_ylabel")
ax[1].plot(x,z)
ax[1].set_xlabel("set_xlabel")
ax[1].set_ylabel("set_ylabel")

plt.show();

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here

y1=x**2
y2=np.exp(x)

fig, ax = plt.subplots(nrows=2,ncols=1, figsize=(10,7))

ax[0].plot(x,y1)
ax[0].plot(x,y2)
ax[0].set_xscale("linear")
ax[0].set_yscale("linear")

ax[1].plot(x,y1)
ax[1].plot(x,y2)
ax[1].set_xscale("log")
ax[1].set_yscale("log")

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
data = pd.read_csv("vehicles.csv")
data
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
fig, ax = plt.subplots()

ax.scatter(x=data["Combined MPG"],y=data["Highway MPG"])
ax.set_xlabel("Combined MPG")
ax.set_ylabel("Highway MPG")

plt.show()

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
fig, ax = plt.subplots()
ax.boxplot(x=data["CO2 Emission Grams/Mile"])
plt.show()

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here

fig, ax = plt.subplots()
ax.hist(x=data["Fuel Barrels/Year"], bins=10)
plt.show()

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
fig, ax = plt.subplots()
ax.bar(data['Fuel Type'],data['City MPG'])
# Out:
# <BarContainer object of 35952 artists>
