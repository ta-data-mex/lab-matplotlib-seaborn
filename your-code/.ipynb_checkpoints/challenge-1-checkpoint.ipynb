# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
plt.subplots()
row_1 = plt.subplot(3,1,1)
row_1.plot(x,y)
row_2 = plt.subplot(3,1,2)
row_2.plot(x,z);

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
fig, ax = plt.subplots(nrows=2, ncols=1)
ax[0].title.set_text('X vs Y')
ax[0].plot(x, y)
ax[1].title.set_text('X vs Z')
ax[1].plot(x, z)
#plt.xticks(rotation=90)

plt.show();

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(8, 8))
ax[0].title.set_text('X vs Y')
ax[0].plot(x, y)
ax[1].title.set_text('X vs Z')
ax[1].plot(x, z)
#plt.xticks(rotation=90)

plt.show();

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(8, 8))
ax[0].set_xlabel('X')
ax[0].set_ylabel('Y')
ax[0].plot(x, y)
ax[1].set_xlabel('X')
ax[1].set_ylabel('Z')
ax[1].plot(x, z)
#plt.xticks(rotation=90)

plt.show();

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
x = np.arange(0,10)
y = x*2
z = np.exp(x)

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(8, 8))

ax[0].set_xlabel('X')
ax[0].set_ylabel('V.Dep')
ax[0].plot(x,y,color='r',label='x^2')
ax[0].plot(x,z,color='b',label='x_exp')
ax[0].title.set_text('Linear')

ax[1].set_xlabel('X')
ax[1].set_ylabel('V.Dep')
ax[1].plot(x,y,color='r',label='x^2')
ax[1].plot(x,z,color='b',label='x_exp')
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[1].title.set_text('Log-Log')


plt.show();

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
df=pd.read_csv(r'C:\Users\danie\Documents\data_analytics_bootcamp\lab-matplotlib-seaborn\your-code\vehicles.csv')
X = df["Combined MPG"]
Y = df["Highway MPG"]

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,5))
plt.scatter(X, Y);

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
#  14  Fuel Cost/Year           35952 non-null  int64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 4.1+ MB

# %%
plt.boxplot(df["CO2 Emission Grams/Mile"])
plt.show;

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
plt.hist(df["Fuel Barrels/Year"]);

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
x = df['Fuel Type']
y = df['City MPG']

plt.bar(x,y)
plt.xticks(rotation='vertical')
plt.show();
