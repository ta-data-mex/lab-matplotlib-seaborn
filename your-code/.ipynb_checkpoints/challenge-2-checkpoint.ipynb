# %% [markdown]
# # Challenge 2

# %% [markdown]
# In this lab you will partner with another student to conduct **[pair programming](https://en.wikipedia.org/wiki/Pair_programming)**. In the next 60 minutes there will be 2 coding sessions of 30 minutes each. In each sessoin, one student will be the **driver** to write the code to solve the problem while the other student will be the **observer** to watch and review. There will be several iterations of your code because the observer will help the driver review the codes and make improvements until the 15 minute session ends. After the coding session ends, the driver and observer will switch roles.

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Preparation
#
# #### Import the `Fitbit2.csv` file and name your dataset `fitbit`

# %%
fitbit=pd.read_csv('Fitbit2.csv')
fitbit.head(3)
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# 0               1680  ...        0.403891    Friday           4.0
# 1               2248  ...        8.767545  Saturday           5.0
# 2               1719  ...        6.567891    Sunday           6.0
#
#    Work_or_Weekend  Hours Sleep Sleep efficiency  Yesterday_sleep  \
# ...

# %% [markdown]
# ## Coding Session I - 30 minutes
#
# From the Fitbit data, we want to visually understand:
#
# 1. **How the average number of steps change by month. Use the appropriate visualization to show the median steps by month?**
# 1. **Is Fitbitter more active on weekend or workdays?**
#
# ##### All plots must be in the same jupyter notebook cell.
#
# Hints:
#
# - Use `Months_encoded` and `Week_or Weekend` columns
# - Use `matplolib.pyplot` object oriented API
# - Set your size figure to `12,4`
# - Explore `plt.sca`
# - Explore `plt.xticks`
# - Save your figures

# %%
# Driver 1 enter codes here
# Q1: How the average number of steps change by month?
# Step 1 - new df with the only important columns for this question
fitbit_month_steps = fitbit[['Date', 'Steps']]

# El siguiente código nos arrojaría resultados diarios, que no es exactamente lo que queremos. 

#fitbit_month_steps.groupby('Date')
#ax = sns.barplot(x="Date", y="Steps", data=fitbit_month_steps)
#ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %%
# Step 2: Clustering Date by Month
# 2.1 Check the type of variable 'Date'
fitbit_month_steps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 2 columns):
# Date     367 non-null object
# Steps    367 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 5.8+ KB

# %%
# 2.2 Convert the type of the column Date to datetime64
fitbit_month_steps.Date = pd.to_datetime(fitbit_month_steps.Date, format='%Y/%m/%d')
fitbit_month_steps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 2 columns):
# Date     367 non-null datetime64[ns]
# Steps    367 non-null int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 5.8 KB
# C:\Users\Dell\Anaconda3\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
# 2.3 Set the Date column as the index of the DataFrame
fitbit_month_steps = fitbit_month_steps.set_index('Date', drop = True)
fitbit_month_steps.head()
# Out:
#             Steps
# Date
# 2015-05-08    905
# 2015-05-09  18925
# 2015-05-10  14228
# 2015-05-11   6756
# 2015-05-12    502

# %%
# 2.4 Group the Days by months and take the mean values within steps
fitbit_month_steps = fitbit_month_steps.resample('M').median() 
fitbit_month_steps
# Out:
#               Steps
# Date
# 2015-05-31   7127.0
# 2015-06-30  12935.5
# 2015-07-31  10644.0
# 2015-08-31  12213.0
# 2015-09-30   9343.0
# 2015-10-31   7865.0
# 2015-11-30   9453.5
# 2015-12-31   8531.0
# 2016-01-31  10366.0
# 2016-02-29   9235.0
# 2016-03-31  11122.0
# 2016-04-30  13846.5
# 2016-05-31  16382.0

# %%
# Step3: Plot
# ax = sns.barplot(x="Date", y="Steps", data=fitbit_month_steps) --> esta línea me marca error porque
# no puede interpretar el input 'Date'.
fitbit_month_steps.reset_index().plot(x='Date', y='Steps')

# %%
# Dios mío, me acabo de dar cuenta que existía la variable 'Months'... lección aprendida, 
# analizar todo el dataframe antes de ponerse a codear... 
plt.figure(figsize=(12,4))
sns.boxplot(x='Months', y = 'Steps', data = fitbit)

# %%
# Q2: Is Fitbitter more active on weekend or workdays?
#Step 1: new df with the only important columns for this question
fitbit_weekend_steps = fitbit[['Days', 'Steps']]
fitbit_weekend_steps.head(4)
# Out:
#        Days  Steps
# 0    Friday    905
# 1  Saturday  18925
# 2    Sunday  14228
# 3    Monday   6756

# %%
# Step 2: Clustering Date by Weekend or not Weekend
def dummy_days(x):
    if x == 'Saturday' or x == 'Sunday':
        return 1
    return 0

# 2.1 apply the function to the Days column and create a new column
fitbit_weekend_steps['weekend'] = fitbit_weekend_steps['Days'].apply(dummy_days)
fitbit_weekend_steps.head()
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        Days  Steps  weekend
# 0    Friday    905        0
# 1  Saturday  18925        1
# 2    Sunday  14228        1
# 3    Monday   6756        0
# 4   Tuesday    502        0

# %%
# Group By weekends or not weekends and take the mean steps of each group 
steps_by_weekend = fitbit_weekend_steps.groupby('weekend')[['Days', 'Steps']].mean()
steps_by_weekend
# Out:
#                 Steps
# weekend
# 0        10144.572519
# 1        10064.238095

# %%
# Plot (reset index first) 
steps_by_weekend.plot.bar()

# %%
# Después de hacer tooodo esto me di cuenta que había una variable que se llama Work_or_Weekend, LOOOL
plt.figure(figsize=(4,4))
sns.boxplot(x='Work_or_Weekend', y='Steps',  data = fitbit)

# %% [markdown]
# ## Coding Session II - 30 minutes
#
# **Write a loop to plot 3 scatter plots of the following features:**
#
# 1. **`Minutes Lightly Active`  vs `Steps`**
# 1. **`Minutes Very Active` vs `Steps`**
# 1. **`Minutes Sedentary` vs `Steps`**

# %%
# Driver 2 enter codes here
#Step 1: new df with the only important columns for this question

fitbit_minutes_steps = fitbit[['Date', 'Steps', 'Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']]
fitbit_minutes_steps.head()
# Out:
#          Date  Steps  Minutes Lightly Active  Minutes Very Active  \
# 0  2015-05-08    905                      46                    0
# 1  2015-05-09  18925                     316                   60
# 2  2015-05-10  14228                     226                   77
# 3  2015-05-11   6756                     190                    4
# 4  2015-05-12    502                     171                    0
#
#    Minutes Sedentary
# 0              1.355
# 1            611.000
# 2            602.000
# 3            749.000
# 4            876.000

# %%
sns.scatterplot(x="Minutes Lightly Active", y="Steps", data=fitbit_minutes_steps)

# %%
sns.scatterplot(x="Minutes Very Active", y="Steps", data=fitbit_minutes_steps)

# %%
sns.scatterplot(x="Minutes Sedentary", y="Steps", data=fitbit_minutes_steps)

# %%
# Step 2: Write a loop to plot the 3 scatter plots at the same time
plt.figure(figsize=(22,12))
for i in ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']:
    plt.scatter(fitbit[i], fitbit['Steps'])

plt.ylabel('Steps')
plt.legend(['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary'])
