# %% [markdown]
# # Challenge 2

# %% [markdown]
# In this lab you will partner with another student to conduct **[pair programming](https://en.wikipedia.org/wiki/Pair_programming)**. In the next 60 minutes there will be 2 coding sessions of 30 minutes each. In each sessoin, one student will be the **driver** to write the code to solve the problem while the other student will be the **observer** to watch and review. There will be several iterations of your code because the observer will help the driver review the codes and make improvements until the 15 minute session ends. After the coding session ends, the driver and observer will switch roles.

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
'''
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
'''
# Out:
# '\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport seaborn as sns\n%matplotlib inline\n'

# %% [markdown]
# ## Preparation
#
# #### Import the `Fitbit2.csv` file and name your dataset `fitbit`

# %%
fitbit=pd.read_csv('Fitbit2.csv')

fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# ## Coding Session I - 30 minutes
#
# From the Fitbit data, we want to visually understand:
#
# 1. **How the average number of steps change by month. Use the appropriate visualization to show the median steps by month?**
# 1. **Is Fitbitter more active on weekend or workdays?**
#
# ##### All plots must be in the same jupyter notebook cell.
#
# Hints:
#
# - Use `Months_encoded` and `Week_or Weekend` columns
# - Use `matplolib.pyplot` object oriented API
# - Set your size figure to `12,4`
# - Explore `plt.sca`
# - Explore `plt.xticks`
# - Save your figures

# %%
# Driver 1 enter codes here

#Import the libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
#1 How the average number of steps change by month. Use the appropriate visualization to show the median steps by month.
#Primero tenemos que obtener the average number of steps by month
fitbit_mean = fitbit.groupby("Months").mean()#.sort_values(by="Months_encoded")
fitbit_mean
# Out:
#            Calorie burned         Steps   Distance     Floors  \
# Months
# April         3030.800000  13079.033333  11.190667  11.566667
# August        2844.967742  11584.774194   9.059677  14.129032
# December      2737.290323   8470.064516   7.460323   8.935484
# February      2600.100000   8922.866667   7.143667   9.666667
# January       2812.806452   9892.064516   7.912581   8.580645
# July          2699.935484   9193.322581   8.695484  16.000000
# June          2971.666667  12536.166667  10.881667  24.366667
# March         2281.258065  10312.935484   9.184194   9.935484
# May           2836.580645  10620.096774   8.799677  10.741935
# November      2578.066667   9467.466667   7.927333   8.033333
# October       2608.838710   8272.451613   6.570000   6.709677
# September     2908.000000   9191.333333   7.836333  12.266667
#
#            Minutes Sedentary  Minutes Lightly Active  Minutes Fairly Active  \
# Months
# ...

# %%
#Hacemos la gráfica correspondiente. Scatter no dice mucho, entonces la hacemos lineal

#sns.lmplot("Months_encoded", "Steps", data = fitbit_mean, fit_reg=False)

sns.lineplot(fitbit_mean.Months_encoded, fitbit_mean.Steps)   #La gráfica lineal dice mucho más que la lineal

# %%
#EXTRA POINT (y me gustó cómo se ve)
#Si quisieramos la median
grafica = sns.boxplot(x="Months", y="Steps", data=fitbit)
grafica.set_xticklabels(grafica.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'May'),
#  Text(0, 0, 'June'),
#  Text(0, 0, 'July'),
#  Text(0, 0, 'August'),
#  Text(0, 0, 'September'),
#  Text(0, 0, 'October'),
#  Text(0, 0, 'November'),
#  Text(0, 0, 'December'),
#  Text(0, 0, 'January'),
#  Text(0, 0, 'February'),
#  Text(0, 0, 'March'),
#  Text(0, 0, 'April')]

# %%
#Intento 3
fitbit_weekend = fitbit.groupby(['Months', 'Work_or_Weekend', "Months_encoded"], as_index=False)['Steps'].sum() #as_index=FALSE evita hacerlos índices
fitbit_weekend = pd.DataFrame(fitbit_weekend)
fitbit_weekend
# Out:
#        Months  Work_or_Weekend  Months_encoded   Steps
# 0       April                0               4   74571
# 1       April                1               4  317800
# 2      August                0               8  124629
# 3      August                1               8  234499
# 4    December                0              12   77807
# 5    December                1              12  184765
# 6    February                0               2   87058
# 7    February                1               2  180628
# 8     January                0               1   96184
# 9     January                1               1  210470
# 10       July                0               7   70808
# 11       July                1               7  214185
# 12       June                0               6  101737
# 13       June                1               6  274348
# 14      March                0               3   39530
# 15      March                1               3  280171
# ...

# %%
#Responder la pregunta
week_weekend_graf = sns.barplot(x="Months_encoded", y="Steps", hue="Work_or_Weekend", data=fitbit_weekend) #Si quierdes que diga el nombre del mes le pones "Month"
week_weekend_graf.set_xticklabels(week_weekend_graf.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8'),
#  Text(0, 0, '9'),
#  Text(0, 0, '10'),
#  Text(0, 0, '11'),
#  Text(0, 0, '12')]

# %%
#Juntmos las dos gráficas

plt.figure(figsize=(12,4))

sns.lineplot(fitbit_mean.Months_encoded, fitbit_mean.Steps)
plt.savefig('Graficas1.png')
plt.show()

week_weekend_graf = sns.barplot(x="Months_encoded", y="Steps", hue="Work_or_Weekend", data=fitbit_weekend)
week_weekend_graf.set_xticklabels(week_weekend_graf.get_xticklabels(),rotation=90)

plt.savefig('Graficas2.png')   #save graph siempre tiene que ir antes de plt.show
plt.show()

# %% [markdown]
# ## Coding Session II - 30 minutes
#
# **Write a loop to plot 3 scatter plots of the following features:**
#
# 1. **`Minutes Lightly Active`  vs `Steps`**
# 1. **`Minutes Very Active` vs `Steps`**
# 1. **`Minutes Sedentary` vs `Steps`**

# %%
# Driver 2 enter codes here

#Voy a subseccionar el data frame a que sólo tenga Steps y las otras tres variables
fitbit_reducida = fitbit[["Steps", "Minutes Lightly Active", "Minutes Very Active", "Minutes Sedentary"]]
fitbit_reducida
# Out:
#      Steps  Minutes Lightly Active  Minutes Very Active  Minutes Sedentary
# 0      905                      46                    0              1.355
# 1    18925                     316                   60            611.000
# 2    14228                     226                   77            602.000
# 3     6756                     190                    4            749.000
# 4      502                     171                    0            876.000
# 5      779                     172                   18            726.000
# 6     5614                     216                    1            782.000
# 7     8169                     218                    7            801.000
# 8    19971                     247                  118            532.000
# 9      852                     186                   73            606.000
# 10   11998                     189                   51            936.000
# ...

# %%
#Creamos columnas para que itere
x_col = "Steps"
y_cols = ["Minutes Lightly Active", "Minutes Very Active", "Minutes Sedentary"]

# %%
#Hacemos el loop

for y_col in y_cols:
    figure = plt.figure
    ax = plt.gca() #No entiendo qué hace esto
    ax.scatter(fitbit_reducida[x_col], fibit_reducida[y_col])
    ax.set_xlabel(x_col)
    ax.set_ylabel(y_col)
    ax.set_title("{} vs {}".format(x_col, y_col))
    
    plt.legend()
    plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
