# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv(r'/Users/diegoperezo97/Documents/Ironhack – Data Analytics Bootcamp/Module 2/Week 4/Day 3/lab-matplotlib-seaborn/your-code/titanic.csv', low_memory=False)
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
# Your code here

titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# Your code here- numerical variable

titanic.select_dtypes(include=['int64', 'float64'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# Your code here- categorical variable


titanic.select_dtypes(include='object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# Your code here

plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# Your code here

plt.hist(titanic['Age'], bins=20)
plt.title("Age Frecuency of Passengers Aboard the Titanic")
plt.xlabel('Age')
plt.ylabel('Frecuency')
plt.show()

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# Your code here

fig, (ax0, ax1, ax2,) = plt.subplots(nrows=1, ncols=3)
ax0.hist(titanic['Age'], bins=10)
ax1.hist(titanic['Age'], bins=20)
ax2.hist(titanic['Age'], bins=50)
plt.show()

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %% [markdown]
# It does affect the plot. As less bins are selected, more data points are assigned into each of them, impacting on the frequency. Contrary, if less bins are selected, data is distributed into more of those bins, representing the distribution more realistically.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# Your code here

sns.histplot(data=titanic['Age']).set_title("Age Frecuency of Passengers Aboard the Titanic")
plt.xlabel('Age')
plt.ylabel('Frecuency')
# Out:
# Text(0, 0.5, 'Frecuency')

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
titanic_gender = pd.pivot_table(
    titanic,
    values=['PassengerId'],
    index=['Gender'],
    aggfunc={'PassengerId': 'count'}
).reset_index()

titanic_gender
# Out:
#    Gender  PassengerId
# 0  female          466
# 1    male          843

# %%
# Your code here- 1st way

plt.bar(titanic_gender['Gender'], height=titanic_gender['PassengerId'])
plt.title("Genders of Passengers Aboard the Titanic")
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.show()

# %%
# Your code here- 2nd way

sns.barplot(x=titanic_gender['Gender'], y=titanic_gender['PassengerId'])
plt.title("Genders of Passengers Aboard the Titanic")
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
titanic_pclass = pd.pivot_table(
    titanic,
    values=['PassengerId'],
    index=['Pclass'],
    aggfunc={'PassengerId': 'count'}
).reset_index()

titanic_pclass
# Out:
#    Pclass  PassengerId
# 0       1          323
# 1       2          277
# 2       3          709

# %%
# Your code here

sns.barplot(x=titanic_pclass['Pclass'], y=titanic_pclass['PassengerId'])
plt.title("Classes Aboard the Titanic")
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
titanic['Age'].describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
titanic['Age'].mode()
# Out:
# 0    24.0
# dtype: float64

# %%
# Your code here

summary = pd.DataFrame(titanic['Age'].describe()).reset_index().rename(columns={'index': 'Feature', 'Age': 'Magnitude'})
summary.drop(index=0, inplace=True)

# %%
sns.scatterplot(data=summary, x='Feature', y='Magnitude', hue='Feature', size='Feature', legend=False)
# Out:
# <AxesSubplot:xlabel='Feature', ylabel='Magnitude'>

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
sns.boxplot(x=titanic["Age"])
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# 1309 passengers' ages were analized. ~30 years was the average age. Median is 22 years old while mean is ~30 years. This might be becuase of the number of upper outliers we have. I would like to dive deeper into ages of 0. Were they babies or are we missing that data?

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
# Your code here

sns.histplot(data=titanic['Age']).set_title("Age Frecuency of Passengers Aboard the Titanic")
plt.xlabel('Age')
plt.ylabel('Frecuency')
# Out:
# Text(0, 0.5, 'Frecuency')

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %% [markdown]
# Histogram confirmed some of the findings from the boxplot. We can see that age-group ~22-24 is the most common. Previously we discussed that median is around 22 years while mode is 24. This two findings are confirmed by the frequency of the 22-24 age-group. Distribution is not normal and we have a right skewness.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
# Your code-1st way

sns.scatterplot(data=titanic, x='Age', y='Fare')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
# Your code-2nd way

correlation_1 = titanic['Age'].corr(titanic['Fare'])
correlation_1
# Out:
# 0.17135508596244753

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
df_corr = titanic.select_dtypes(include=['int64', 'float64']).corr()

# %%
# Your code here

cmap = sns.diverging_palette(6, 255, as_cmap=True)
sns.heatmap(df_corr, cmap=cmap, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %% [markdown]
# I wouldn't conclude that we have positively related variables as none of the correlations are greater than 0.4. Nevetheless, we should have under consideration the correlation of Sibsp and Parch. On the other hand, we do have negatively related variables such as Pclass and Fare, which makes me noise as I would assume that when the class goes down, so does the price. Same as with the age. I would assume that when age goes up, class would go up as (normally) older people are more economically stable.

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
# Your code here

titanic_pclass_age = pd.pivot_table(
    titanic,
    values=['Age'],
    index=['Pclass'],
    aggfunc={'Age': 'mean'}
).reset_index()

titanic_pclass_age
# Out:
#    Pclass        Age
# 0       1  39.555048
# 1       2  29.977433
# 2       3  25.432757

# %%
sns.barplot(x=titanic_pclass_age['Pclass'], y=titanic_pclass_age['Age'])
plt.title("Classes Aboard the Titanic")
plt.xlabel('Class')
plt.ylabel('Average Age of Passenger in Class')
plt.show()

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
# Your code here

titanic_age_gender = pd.pivot_table(
    titanic,
    values=['Age'],
    index=['Gender'],
    aggfunc={'Age': 'mean'}
).reset_index()

titanic_age_gender
# Out:
#    Gender        Age
# 0  female  28.548826
# 1    male  30.614592

# %%
# Your code here

sns.histplot(data=titanic['Age'][titanic['Gender'] == 'male']).set_title("Age Frecuency of Male Passengers Aboard the Titanic")
plt.xlabel('Age')
plt.ylabel('Frecuency')
# Out:
# Text(0, 0.5, 'Frecuency')

# %%
# Your code here

sns.histplot(data=titanic['Age'][titanic['Gender'] == 'female']).set_title("Age Frecuency of Female Passengers Aboard the Titanic")
plt.xlabel('Age')
plt.ylabel('Frecuency')
# Out:
# Text(0, 0.5, 'Frecuency')
