# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
numerical_variables = titanic.select_dtypes(include='number')

# %%
#your code here- categorical variable
categorical_variables=titanic.select_dtypes(exclude ='number')

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
plt.style = 'classic'
plt.figure(figsize=(12, 6))

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
titanic.Age.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
# your code here
fig, axes = plt.subplots(1, 3, figsize=(12, 6))

plt.sca(axes[0])
titanic['Age'].hist(bins=10)

plt.sca(axes[1])
titanic['Age'].hist(bins=20)

plt.sca(axes[2])
titanic['Age'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
"""A mayor cantidad de bins, en este caso, la visualización del plot se dificulta"""
# Out:
# 'A mayor cantidad de bins, en este caso, la visualización del plot se dificulta'

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.histplot(titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
sns.histplot(titanic['Gender'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %%
# your code here- 2nd way
titanic.Gender.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
titanic['Pclass'].value_counts().plot(kind = 'bar')
plt.xlabel('Class')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
plt.boxplot(titanic['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cbe49784f0>,
#   <matplotlib.lines.Line2D at 0x1cbe49787c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1cbe4978b50>,
#   <matplotlib.lines.Line2D at 0x1cbe4978ee0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1cbe49780a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cbe497b2b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cbe497b640>],
#  'means': []}

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
"""la mediana se encuentra por debajo de los 30. El 50 por ciento de los datos se encuentran entre los
20 y 40 años"""
# Out:
# 'la mediana se encuentra por debajo de los 30. El 50 por ciento de los datos se encuentran entre los\n20 y 40 años'

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
sns.violinplot(x = titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
sns.jointplot(x=titanic['Age'], 
              y=titanic['Fare'],
              kind="reg",
              data=titanic)

# %%
# your code-2nd way
sns.regplot(x=titanic['Age'], 
            y=titanic['Fare'],
            data=titanic);

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
titanic_corr = titanic.corr()
ax = sns.heatmap(titanic_corr,annot=True, vmin=0, vmax=1)

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
"""SibSp y Parch"""
# Out:
# 'SibSp y Parch'

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
sns.boxplot(x = titanic['Pclass'], y = titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
#your code here
g = sns.FacetGrid(data = titanic, col="Gender")
g.map(plt.hist, "Age")
