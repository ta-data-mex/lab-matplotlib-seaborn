# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here

titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable

titanic.select_dtypes(['int64', 'float64']).columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
#your code here- categorical variable

titanic.select_dtypes('object').columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here

plt.style.use('classic')
plt.figure(figsize=(12,6))
plt.hist(titanic['Age'])
plt.show()

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here

# plt.style.use('classic')
# plt.figure(figsize=(12,6))
# plt.hist(titanic['Age'],bins=[0, 10, 30, 80])
# plt.show()

sns.set_theme(style='whitegrid')
sns.displot(titanic['Age'], bins=[0, 10, 30, 80])

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here

# Con la distribución de los rangos como se nos fue solicitado pareciera que la distribución de la
# edad de la población se asemeja más a una distribución lineal, cuando en realidad se asemeja una
# distribución normal con tendencia a la izquierda.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here

sns.displot(titanic['Age'])

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way

titanic.groupby('Gender').size().plot(kind='pie')
plt.show()

# %%
# your code here- 2nd way

titanic.groupby('Gender').size().plot(kind='bar')
plt.show()

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here

titanic.groupby('Pclass').size().plot(kind='bar')
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
print(titanic.Age.describe())

titanic.Age.plot(kind='box')
plt.show()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here

# La mayor cantidad de personas estaban entre 22 y 37 años y con algunos registros extraordinarios
# con edad superior a los 60 años.

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here

print(titanic.Age.describe())
titanic.Age.plot(kind='hist')
plt.show()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way

plt.scatter(titanic['Fare'], titanic['Age'])
plt.show()

# %%
# your code-2nd way

sns.jointplot(x=titanic['Fare'], y=titanic['Age']);

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here

mask = np.zeros_like(titanic.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(titanic.corr(), annot=True, mask=mask)
# Out:
# C:\Users\Alejandro\AppData\Local\Temp\ipykernel_18524\523733247.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(titanic.corr(), dtype=np.bool)
# <AxesSubplot:>

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here

# La mayor correlación es entre la 'Edad' y la 'Clase del pasajero', seguido por una correlación medio baja entre la
# 'Edad' y la 'Clase del pasajero'.

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here

for i in titanic.Pclass.unique():
    print('Passenger Class: '+str(i))
    titanic[titanic.Pclass == i].loc[:,'Age'].plot(kind='box')
    plt.show()
# Out:
# Passenger Class: 3
# Passenger Class: 1
# Passenger Class: 2

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here

sns.FacetGrid(titanic, col='Gender').map(sns.histplot, 'Age')
plt.show()
