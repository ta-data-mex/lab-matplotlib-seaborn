# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
numerical = titanic.select_dtypes(include=['number'])
numerical.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
#your code here- categorical variable
categorical = titanic.select_dtypes(exclude=['number'])
categorical.head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
plt.style.use('classic')
plt.figure(figsize=(12,6))
fig, ax = plt.subplots(figsize=(12, 6))

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
# Histogram
titanic['Age'].hist()

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
fig, [ax1, ax2, ax3] = plt.subplots(1,3)
ax1 = titanic['Age'].hist()
ax1.set_title('bins=10')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')   


ax2 = titanic['Age'].hist(bins=20)
ax2.set_title('bins=20')
ax2.set_xlabel('x label')
ax2.set_ylabel('y label')

ax3 = titanic['Age'].hist(bins=50)
ax3.set_title('bins=50')
ax3.set_xlabel('x label')
ax3.set_ylabel('y label')

plt.show()

# %%
fig, [ax1, ax2, ax3] = plt.subplots(1,3)
ax1.hist(titanic['Age'])
ax1.set_title('bins=10')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')   


ax2.hist(titanic['Age'], bins=20)
ax2.set_title('bins=20')
ax2.set_xlabel('x label')
ax2.set_ylabel('y label')

ax3.hist(titanic['Age'], bins=50)
ax3.set_title('bins=50')
ax3.set_xlabel('x label')
ax3.set_ylabel('y label')

plt.show()

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
# When we use the default bin size, the distribution looks normal, when we use bin=50 looks
# almost bimodal.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.distplot(titanic['Age'])

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
titanic['Gender'].value_counts().plot.bar()

# %%
# your code here- 2nd way
labels = ['Male', 'Female']
sizes = [int(len(titanic[titanic['Gender'] == 'male'].Gender)), int(len(titanic[titanic['Gender'] == 'female'].Gender))]
explode = (0, 0.1)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')
plt.show()

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
titanic['Pclass'].value_counts().plot.bar()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
summary = titanic.Age.describe()
summary.plot.bar()
# mmm, that doesn't look appropriate, jeje.

# %%
titanic.boxplot(column="Age")
# that's better.

# %%
sns.violinplot("Age", data=titanic)
# I like this one better.

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
# distribución sesgada a la derecha por muchos outliers (muchos viejitos muy por encima de la media)

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
sns.distplot(titanic['Age'])

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
# la edad, como era de esperarse, se distribuye normal.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
sns.scatterplot(x="Fare", y="Age", data=titanic)

# %%
# your code-2nd way
x = titanic['Fare']
y = titanic.Age
plt.scatter(x,y)
plt.xlabel('Age')
plt.ylabel('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
sns.heatmap(titanic.corr(), xticklabels=titanic.corr().columns, yticklabels=titanic.corr().columns, annot=True)

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
# PClass is highly correlated with the variables Fare, Age and Survived... makes sense...

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
titanic.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
sns.boxplot(x='Pclass', y='Age', data=titanic)

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
age = sns.FacetGrid(titanic, col="Gender")
age.map(plt.hist, 'Age')
