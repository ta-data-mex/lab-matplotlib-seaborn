# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes("float")
# Out:
#       Survived        Age      Fare
# 0          0.0  22.000000    7.2500
# 1          1.0  38.000000   71.2833
# 2          1.0  26.000000    7.9250
# 3          1.0  35.000000   53.1000
# 4          0.0  35.000000    8.0500
# 5          0.0  23.926502    8.4583
# 6          0.0  54.000000   51.8625
# 7          0.0   2.000000   21.0750
# 8          1.0  27.000000   11.1333
# 9          1.0  14.000000   30.0708
# 10         1.0   4.000000   16.7000
# 11         1.0  58.000000   26.5500
# 12         0.0  20.000000    8.0500
# 13         0.0  39.000000   31.2750
# 14         0.0  14.000000    7.8542
# 15         1.0  55.000000   16.0000
# 16         0.0   2.000000   29.1250
# 17         1.0  32.172868   13.0000
# 18         0.0  31.000000   18.0000
# 19         1.0  27.749836    7.2250
# 20         0.0  35.000000   26.0000
# 21         1.0  34.000000   13.0000
# 22         1.0  15.000000    8.0292
# 23         1.0  28.000000   35.5000
# 24         0.0   8.000000   21.0750
# ...

# %%
#your code here- categorical variable
titanic.select_dtypes("object")
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# 5                                      Moran, Mr. James    male
# 6                               McCarthy, Mr. Timothy J    male
# 7                        Palsson, Master. Gosta Leonard    male
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                   Nasser, Mrs. Nicholas (Adele Achem)  female
# 10                      Sandstrom, Miss. Marguerite Rut  female
# 11                             Bonnell, Miss. Elizabeth  female
# 12                       Saundercock, Mr. William Henry    male
# 13                          Andersson, Mr. Anders Johan    male
# ...

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
plt.style.use('classic')
plt.rcParams["figure.figsize"] = [12,6]  #Creo, ño sé bien

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
titanic['Age'].hist()

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
sns.distplot(titanic['Age'], bins=10)
sns.distplot(titanic['Age'], bins=20)
sns.distplot(titanic['Age'], bins=50)
plt.show()

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here

#ntre menor sea el tamaño de los bins más se desagrega la información.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here

#Para hacer distribución de Age con seaborn 
sns.distplot(titanic["Age"])

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
#Método matplotlib

titanic['Gender'].value_counts().plot.bar()

# %%
# your code here- 2nd way
sns.countplot(x='Gender', data=titanic, palette="Greens")

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
sns.countplot(x='Pclass', data=titanic, palette='Reds')

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
titanic.boxplot(column="Age")

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here

#La mediana de edad está en alrededor de los 28 años. El 25% de los datos está en alrededor de 22 años.

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here

#Creo que aquí se puede usar una gráfica de violín
sns.violinplot("Age", data=titanic)

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here

#Sabemos por esta gráfica que la media es mayor que la mediana.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
sns.jointplot(x="Age", y="Fare", data=titanic)

#De esta gráfica no parece que hay una relación imporante

# %%
# your code-2nd way

sns.lmplot("Age", "Fare", data=titanic, fit_reg=True)

#Pues más o menos se ve, pero tampoco es una relación muy marcada

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
sns.heatmap(titanic.corr(), vmin=-1, cmap="Blues", annot=True)

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here

#Los pares con correlación más alta son Fare y Survived; Parch y SibSp; Parch y Fare.

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
graf = sns.boxplot(x="Pclass", y="Age", data=titanic, palette = "coolwarm")
graf.set_xticklabels(graf.get_xticklabels(),rotation=90)
#graf.tick_params(labelsize=20)
# Out:
# [Text(0, 0, '1'), Text(0, 0, '2'), Text(0, 0, '3')]

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
#Ejemplos aquí https://seaborn.pydata.org/generated/seaborn.distplot.html


graf2 = sns.FacetGrid(titanic, col="Gender", palette="Blues")
graf2 = graf2.map(plt.hist, "Age").add_legend()
