# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %%
titanic.tail(10)
# Out:
#       PassengerId  Survived  Pclass  \
# 1299         1300       NaN       3
# 1300         1301       NaN       3
# 1301         1302       NaN       3
# 1302         1303       NaN       1
# 1303         1304       NaN       3
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                  Name  Gender        Age  \
# 1299                  Riordan, Miss. Johanna Hannah""  female  21.762804
# 1300                        Peacock, Miss. Treasteall  female   3.000000
# 1301                           Naughton, Miss. Hannah  female  32.693417
# 1302  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.000000
# 1303                   Henriksson, Miss. Jenny Lovisa  female  28.000000
# 1304                               Spector, Mr. Woolf    male  29.513190
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(include=[float, int]).head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
titanic.select_dtypes(include=[object]).head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
sns.set_style('white')

# %%
sns.set(style='white', palette='deep', rc={'figure.figsize':(12,6)})

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
titanic['Age'].hist()

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
labels=['babies', 'children', 'adults', 'elders']

plt.hist(titanic['Age'], bins=[0,10.00,20.00,50.00,100.00], label=labels, rwidth=5)
plt.xticks([5,15,35,70], ['babies', 'children', 'adults', 'elderly'])
plt.show()

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %% [markdown]
# Yes, bar width follows the bin size

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.violinplot('Age', data=titanic)

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %% [markdown]
# <h2>I'll be using bar graphs because I hate pie graphs :)</h2>

# %%
# your code here- 1st way
titanic['Gender'].value_counts().plot.barh()

# %%
gen = pd.DataFrame(gen)
gen.reset_index(inplace=True)

# %%
# your code here- 2nd way
sns.countplot(titanic['Gender'])

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
titanic['Pclass'].value_counts().plot.barh()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
plt.boxplot(titanic['Age'], meanline=True, showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x111df51d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12645e320>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x111dc6c50>],
#  'medians': [<matplotlib.lines.Line2D at 0x12628b358>],
#  'fliers': [<matplotlib.lines.Line2D at 0x126415be0>],
#  'means': [<matplotlib.lines.Line2D at 0x126415668>]}

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %% [markdown]
# The majority of people in the ship were young adults, with a number of elderly people shoqn in the outliers, but most of the distribution is concentrated along the 20-35years age.

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
sns.stripplot(titanic['Age'])

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %% [markdown]
# Not much

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
plt.scatter(titanic['Age'], titanic['Fare'])

# %%
# your code-2nd way
sns.pairplot(titanic, vars=['Age', 'Fare'])

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
titanic2 = titanic.corr()

# %%
titanic2 = titanic2.select_dtypes(include=[float, int])

# %%
sns.heatmap(data=titanic2)

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %% [markdown]
# The most correlated feature would be Fare and Class.

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
f = lambda x: list(x)
p_class_age = pd.pivot_table(titanic, index=['Pclass'], values=['Age'], aggfunc=f)
p_class_age = [p_class_age.iloc[i][0] for i in range(len(p_class_age))]
plt.boxplot(p_class_age)
plt.xticks([1,2,3], ['class1', 'class2', 'class3'])
plt.show()

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
age_gen = titanic[['Age', 'Gender']]
g = sns.FacetGrid(age_gen, col="Gender")
g.map(plt.hist, 'Age')
